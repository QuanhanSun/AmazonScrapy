# %%
import re
import json
from bs4 import BeautifulSoup as bs
from selenium import webdriver

# %%
import requests
from faker import Factory
fc = Factory.create()

# %%
def search(url):
    #test_url = 'https://www.amazon.in/product-reviews/B07KXBMFCN/ref=cm_cr_arp_d_viewopt_sr?ie=UTF8&filterByStar=all_stars&reviewerType=all_reviews&pageNumber=1#reviews-filter-bar'
    print(url)
    header={'user-agent': random.choice(agents)}
    page=requests.get(url,headers=header)
    if page.status_code==200:
        return page
    else:
      print(page.status_code)
      return "Error"
# Out:
#   File "<ipython-input-8-7e1afb9c35ab>", line 1
#     def search(url):
#              ^
# SyntaxError: invalid character in identifier

# %%
def search(url):
    header = {'User-Agent': fc.user_agent()}
    page=requests.get(url,headers=header)
    if page.status_code==200:
        return page
    else:
        print(page.status_code)
        return "Error"
# Out:
#   File "<ipython-input-12-4e8f3d582287>", line 4
#     if page.status_code==200:
#           ^
# SyntaxError: invalid character in identifier

# %%
link = 'https://www.amazon.in/gp/profile/amzn1.account.AHJVLXHZN5Q4STGIKNZJSWKZ2PHA/ref=cm_cr_arp_d_gw_btm?ie=UTF8'
response2 = search(link)
soup2 = BeautifulSoup(response2.content, 'lxml')
ele = soup2.find_all('span', attrs={'class':'a-size-large a-color-base'})
ele
# data = json.loads()
# print(data)
# Out:
#   File "<ipython-input-5-f86b895cf0b9>", line 1
#     link ='https://www.amazon.in/gp/profile/amzn1.account.AHJVLXHZN5Q4STGIKNZJSWKZ2PHA/ref=cm_cr_arp_d_gw_btm?ie=UTF8'
#         ^
# SyntaxError: invalid character in identifier

# %%
link = 'https://www.amazon.in/gp/profile/amzn1.account.AHJVLXHZN5Q4STGIKNZJSWKZ2PHA/ref=cm_cr_arp_d_gw_btm?ie=UTF8'
response = requests.get(link,headers = {'User-Agent': fc.user_agent()})

# %%
soup = bs(response.content, 'html.parser')
soup
# Out:
# <!DOCTYPE doctype html>
# <!--[if IE 8]><html data-19ax5a9jf="dingo" lang="en-in" class="a-no-js a-lt-ie10 a-lt-ie9 a-ie8"><![endif]--><!--[if IE 9]><html data-19ax5a9jf="dingo" lang="en-in" class="a-no-js a-lt-ie10 a-ie9"><![endif]--><!--[if !(IE 8)&!(IE 9)]><!--><html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in"><!--<![endif]--><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <script type="text/javascript">var ue_t0=ue_t0||+new Date();</script>
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <script type="text/javascript">
# window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
# ...

# %%
soup.find_all("span", attrs={'class': 'a-size-large a-color-base'})
# Out:
# []

# %%
for i in range(10):
    print(fc.user_agent())
# Out:
# Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.0; Trident/5.0)
# Mozilla/5.0 (compatible; MSIE 8.0; Windows NT 5.0; Trident/3.1)
# Opera/9.97.(X11; Linux x86_64; mn-MN) Presto/2.9.188 Version/10.00
# Mozilla/5.0 (compatible; MSIE 7.0; Windows 95; Trident/4.0)
# Mozilla/5.0 (iPod; U; CPU iPhone OS 4_0 like Mac OS X; nds-DE) AppleWebKit/534.34.3 (KHTML, like Gecko) Version/4.0.5 Mobile/8B111 Safari/6534.34.3
# Mozilla/5.0 (X11; Linux i686) AppleWebKit/531.0 (KHTML, like Gecko) Chrome/32.0.825.0 Safari/531.0
# Mozilla/5.0 (Macintosh; PPC Mac OS X 10_12_5; rv:1.9.4.20) Gecko/2020-01-29 15:57:13 Firefox/10.0
# Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_6_7) AppleWebKit/535.0 (KHTML, like Gecko) Chrome/58.0.844.0 Safari/535.0
# Mozilla/5.0 (iPhone; CPU iPhone OS 6_1_6 like Mac OS X) AppleWebKit/536.1 (KHTML, like Gecko) FxiOS/14.0k9718.0 Mobile/44G121 Safari/536.1
# ...
